# %%
import requests
from fake_useragent import UserAgent #for diguising as browser

# %%
url = 'https://www.consumerreports.org/cro/a-to-z-index/products/index.htm'
file_name = 'consumer_report.txt' #outputfilename

# %%
user_agent = UserAgent()

# %%
page = requests.get(url,headers = {'user_agent':user_agent.chrome})

# %%
with open(file_name,'w') as file:
    file.write(page.content.decode('utf-8')) if type(page.content) == bytes else file.write(page.content)

# %%
from bs4 import BeautifulSoup

# %%
def read_file():
    file = open('consumer_report.txt')
    data = file.read()
    file.close()
    return data

# %%
soup = BeautifulSoup(read_file(),'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://www.consumerreports.org/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <title>
#    A-Z from ConsumerReports.org
#   </title>
#   <link href="https://www.consumerreports.org/cro/a-to-z-index/products/index.htm" rel="canonical"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="free" name="pagePayState"/>
#   <meta content="Complete listing of ConsumerReports.org products from A to Z." name="description"/>
#   <meta content="Top Product Topics from ConsumerReports.org." name="searchTitle"/>
#   <link href="https://cdn.cr.org/etc/designs/cr/clientlibs/component/globalFooter-new.css" rel="stylesheet"/>
# ...

# %%
#for product types
attrib = {'class':'products-a-z__results__item'}
product_name = soup.find_all(attrs = attrib)

# %%
for produc in product_name:
    print(produc.string)
# Out:
#                                     Air Conditioners
#
#
#                                     Air Filters
#
#
#                                     Air Fryers
#
#
#                                     Air Mattresses
#
#
#                                     Air Purifiers
#
#
#                                     Airline Travel
#
#
#                                     All-Purpose Cleaners
#
#
#                                     Antivirus Software
#
#
#                                     Appliance Stores
#
#
#                                     Athletic shoes
#
#
#                                     Baby Bathtubs
#
#
#                                     Baby Food
#
#
#                                     Baby formulas
#
#
#                                     Baby Monitors
#
#
#                                     Backpack Carriers
#
#
#                                     Backpacks
#
#
#                                     Bacon
#
#
# ...

# %%
#For product_links in HTML

product_links = soup.find_all('a',class_='products-a-z__results__item')

# %%
for link in product_links:
    print('http://www.consumerreports.org' + link['href'])
# Out:
# http://www.consumerreports.org/cro/air-conditioners.htm
# http://www.consumerreports.org/cro/air-filters.htm
# http://www.consumerreports.org/cro/air-fryers.htm
# http://www.consumerreports.org/cro/air-mattresses.htm
# http://www.consumerreports.org/cro/air-purifiers.htm
# http://www.consumerreports.org/cro/airline-travel.htm
# http://www.consumerreports.org/cro/all-purpose-cleaners.htm
# http://www.consumerreports.org/cro/antivirus-software.htm
# http://www.consumerreports.org/cro/appliance-stores.htm
# http://www.consumerreports.org/cro/athletic-shoes/buying-guide/index.htm
# http://www.consumerreports.org/cro/baby-bathtubs/buying-guide/index.htm
# http://www.consumerreports.org/cro/baby-food/buying-guide/index.htm
# http://www.consumerreports.org/cro/baby-formula/buying-guide/index.htm
# http://www.consumerreports.org/cro/baby-monitors.htm
# http://www.consumerreports.org/cro/backpack-carriers/buying-guide/index.htm
# ...

# %%
#By dictionary method
#Another method for navigating tag and accesing product_items
product_items = [div.a.string for div in soup.find_all('div',class_= 'crux-body-copy') ]

# %%
for product in product_items:
    print(product)
# Out:
#                                     Air Conditioners
#
#
#                                     Air Filters
#
#
#                                     Air Fryers
#
#
#                                     Air Mattresses
#
#
#                                     Air Purifiers
#
#
#                                     Airline Travel
#
#
#                                     All-Purpose Cleaners
#
#
#                                     Antivirus Software
#
#
#                                     Appliance Stores
#
#
#                                     Athletic shoes
#
#
#                                     Baby Bathtubs
#
#
#                                     Baby Food
#
#
#                                     Baby formulas
#
#
#                                     Baby Monitors
#
#
#                                     Backpack Carriers
#
#
#                                     Backpacks
#
#
#                                     Bacon
#
#
# ...

# %%
#Navigating with loops
product_links = [div.a['href'] for div in soup.find_all('div',class_= 'crux-body-copy') ]

# %%
#product_hyperlinks
for product in product_links:
    print('http://www.consumerreports.org' + product)
# Out:
# http://www.consumerreports.org/cro/air-conditioners.htm
# http://www.consumerreports.org/cro/air-filters.htm
# http://www.consumerreports.org/cro/air-fryers.htm
# http://www.consumerreports.org/cro/air-mattresses.htm
# http://www.consumerreports.org/cro/air-purifiers.htm
# http://www.consumerreports.org/cro/airline-travel.htm
# http://www.consumerreports.org/cro/all-purpose-cleaners.htm
# http://www.consumerreports.org/cro/antivirus-software.htm
# http://www.consumerreports.org/cro/appliance-stores.htm
# http://www.consumerreports.org/cro/athletic-shoes/buying-guide/index.htm
# http://www.consumerreports.org/cro/baby-bathtubs/buying-guide/index.htm
# http://www.consumerreports.org/cro/baby-food/buying-guide/index.htm
# http://www.consumerreports.org/cro/baby-formula/buying-guide/index.htm
# http://www.consumerreports.org/cro/baby-monitors.htm
# http://www.consumerreports.org/cro/backpack-carriers/buying-guide/index.htm
# ...

# %%
products = {}   # product name - key product link - value

# %%
products = {div.a.string:'http://www.consumerreports.org' + div.a['href'] for div in soup.find_all('div',class_='crux-body-copy')}

# %%
for key,value in products.items():
    print(key , '-->',value)
# Out:
#                                     Air Conditioners
#                                  --> http://www.consumerreports.org/cro/air-conditioners.htm
#
#                                     Air Filters
#                                  --> http://www.consumerreports.org/cro/air-filters.htm
#
#                                     Air Fryers
#                                  --> http://www.consumerreports.org/cro/air-fryers.htm
#
#                                     Air Mattresses
#                                  --> http://www.consumerreports.org/cro/air-mattresses.htm
#
#                                     Air Purifiers
#                                  --> http://www.consumerreports.org/cro/air-purifiers.htm
#
#                                     Airline Travel
#                                  --> http://www.consumerreports.org/cro/airline-travel.htm
#
#                                     All-Purpose Cleaners
# ...
